# %%
import Preprocessing

Preprocessing.preprocessing_2018()
# Out:
# ...
#       age                                          workclass     education  \
# 1      18                                            Private  Some-college
# 2      53                                        Federal-gov       HS-grad
# 8      41                                            Private       HS-grad
# 9      18  Self-employed in own not incorporated business...  Some-college
# 14     21                                        Federal-gov  Some-college
# ...    ..                                                ...           ...
# 38775  20  Self-employed in own not incorporated business...  Some-college
# 38779  63                                            Private       HS-grad
# 38782  65                                            Private     Bachelors
# 38783  37                                            Private       HS-grad
# 38784  18                                            Private       HS-grad
#
# ...

# %%
Preprocessing.preprocessing_old("..\\data\\adult.csv")
# Out:
# c:\Users\lisaa\Documents\HCML_project\Preprocessing\Preprocessing.py:191: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mask = old_data.applymap(lambda x: '?' in str(x))
#         age workclass     education marital.status         occupation  \
# 1      82.0   Private       HS-grad        Widowed    Exec-managerial
# 3      54.0   Private       7th-8th       Divorced  Machine-op-inspct
# 4      41.0   Private  Some-college      Separated     Prof-specialty
# 5      34.0   Private       HS-grad       Divorced      Other-service
# 6      38.0   Private          10th      Separated       Adm-clerical
# ...     ...       ...           ...            ...                ...
# 30111   NaN       NaN           NaN            NaN                NaN
# 30121   NaN       NaN           NaN            NaN                NaN
# 30141   NaN       NaN           NaN            NaN                NaN
# ...
